# %%
numbers = input("Enter comma-separated numbers: ")

number_list = numbers.split(",")

number_tuple = tuple(number_list)

print("List:", number_list)
print("Tuple:", number_tuple)
# Out:
# Enter comma-separated numbers:  5,9,13,12
# List: ['5', '9', '13', '12']
# Tuple: ('5', '9', '13', '12')

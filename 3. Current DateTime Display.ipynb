# %%
from datetime import datetime

current_datetime = datetime.now()

print("Current date and time:")
print(current_datetime)
# Out:
# Current date and time:
# 2026-02-24 21:23:40.595671

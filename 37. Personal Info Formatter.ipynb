# %%
def display_info():
    name = "Harish"
    age = 22
    address = "Deori, Chhattisgarh, India"

    print("Name:", name)
    print("Age:", age)
    print("Address:", address)

display_info()
# Out:
# Name: Harish
# Age: 22
# Address: Deori, Chhattisgarh, India
